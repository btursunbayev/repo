# %% [markdown]
# # P4 Assignment
#
# For this assignment, you will be writing P4 code which enables a switch to function as a joint router and firewall for an IPv6 network. The network topology is shown below.
# <img src="./images/assignment4_topology.png" width="1000px">
#
# Note: h23 will only be configured for a final test case, and begins unconfigured.
#
# Authored by Alexander Wolosewicz, IIT, adapting some code by Nishanth Shyamkumar, IIT

# %% [markdown]
# ## Create topology
# The creation of the topology is done automatically for you. If you ever close the Jupyter kernel, or it crashes, all variable values are lost. The below cell can be executed to reset all the variable values.
# Note that if the slice expires (24 hours after creation) you must start from the beginning. Any progress made in files (the shell script or P4 code) is safe as long as it is saved.
# Make sure to retype your student ID for "student_id".

# %%
student_id = "btursunbayev"
verbose = False

# %%
# Setup slice, or retrieve values if slice already exists
from scripts import funcs

slice_values = funcs.setup(student_id=student_id, verbose=verbose)

vslice = slice_values['slice']
configs = slice_values['configs']
ips = slice_values['ips']
macs = slice_values['macs']
ifaces = slice_values['ifaces']
subnets = slice_values['subnets']
hosts = slice_values['hosts']
switches = slice_values['switches']
gateways = slice_values['gateways']
# Out:
# Retry: 13, Time: 335 sec
# <style type="text/css">
# #T_34950 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_34950 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_34950 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_34950_row0_col0, #T_34950_row0_col1, #T_34950_row1_col0, #T_34950_row1_col1, #T_34950_row2_col0, #T_34950_row2_col1, #T_34950_row3_col0, #T_34950_row3_col1, #T_34950_row4_col0, #T_34950_row4_col1, #T_34950_row5_col0, #T_34950_row6_col0, #T_34950_row6_col1, #T_34950_row7_col0, #T_34950_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_34950_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_34950">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_34950_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_34950_row0_col1" class="data row0 col1" >1298b3f6-cf9d-432f-861b-eea99985d515</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_34950_row1_col1" class="data row1 col1" >btursunbayev_p4_1</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_34950_row2_col1" class="data row2 col1" >2025-11-27 03:44:55 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_34950_row3_col1" class="data row3 col1" >2025-11-26 03:44:55 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_34950_row4_col1" class="data row4 col1" >a46f4bd3-be82-4529-9107-813839492c9f</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_34950_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_34950_row6_col1" class="data row6 col1" >btursunbayev@hawk.illinoistech.edu</td>
#     </tr>
#     <tr>
#       <td id="T_34950_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_34950_row7_col1" class="data row7 col1" >cf66056e-f1bc-4c3a-a04b-cf9644dc353b</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6b498 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_6b498 th {
#   text-align: left;
# }
# #T_6b498 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6b498 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6b498 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6b498_row0_col0, #T_6b498_row0_col1, #T_6b498_row0_col2, #T_6b498_row0_col3, #T_6b498_row0_col4, #T_6b498_row0_col5, #T_6b498_row0_col6, #T_6b498_row0_col7, #T_6b498_row0_col8, #T_6b498_row0_col9, #T_6b498_row0_col10, #T_6b498_row0_col13, #T_6b498_row0_col14, #T_6b498_row0_col15, #T_6b498_row1_col0, #T_6b498_row1_col1, #T_6b498_row1_col2, #T_6b498
level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6b498_row0_col0" class="data row0 col0" >a8978002-ade0-4617-a0bf-0323a97175e7</td>
#       <td id="T_6b498_row0_col1" class="data row0 col1" >h11</td>
#       <td id="T_6b498_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_6b498_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_6b498_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_6b498_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_6b498_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_6b498_row0_col7" class="data row0 col7" >eduky-w16.fabric-testbed.net</td>
#       <td id="T_6b498_row0_col8" class="data row0 col8" >EDUKY</td>
#       <td id="T_6b498_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_6b498_row0_col10" class="data row0 col10" >2610:1e0:1700:206:f816:3eff:fee2:9435</td>
#       <td id="T_6b498_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_6b498_row0_col12" class="data row0 col12" ></td>
#       <td id="T_6b498_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fee2:9435</td>
#       <td id="T_6b498_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_6b498_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_6b498_row1_col0" class="data row1 col0" >0c15a351-115f-408e-beff-a419764102a9</td>
#       <td id="T_6b498_row1_col1" class="data row1 col1" >h12</td>
#       <td id="T_6b498_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_6b498_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_6b498_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_6b498_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_6b498_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_6b498_row1_col7" class="data row1 col7" >eduky-w16.fabric-testbed.net</td>
#       <td id="T_6b498_row1_col8" class="data row1 col8" >EDUKY</td>
#       <td id="T_6b498_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_6b498_row1_col10" class="data row1 col10" >2610:1e0:1700:206:f816:3eff:fed1:442b</td>
#       <td id="T_6b498_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_6b498_row1_col12" class="data row1 col12" ></td>
#       <td id="T_6b498_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fed1:442b</td>
#       <td id="T_6b498_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_6b498_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_6b498_row2_col0" class="data row2 col0" >fa3bf4cd-edce-41c7-9247-db626a102521</td>
#       <td id="T_6b498_row2_col1" class="data row2 col1" >h13</td>
#       <td id="T_6b498_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_6b498_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_6b498_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_6b498_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td
# <style type="text/css">
# #T_59a58 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_59a58 th {
#   text-align: left;
# }
# #T_59a58 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_59a58 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_59a58 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_59a58_row0_col0, #T_59a58_row0_col1, #T_59a58_row0_col2, #T_59a58_row0_col3, #T_59a58_row0_col4, #T_59a58_row0_col5, #T_59a58_row0_col6, #T_59a58_row1_col0, #T_59a58_row1_col1, #T_59a58_row1_col2, #T_59a58_row1_col3, #T_59a58_row1_col4, #T_59a58_row1_col5, #T_59a58_row1_col6, #T_59a58_row2_col0, #T_59a58_row2_col1, #T_59a58_row2_col2, #T_59a58_row2_col3, #T_59a58_row2_col4, #T_59a58_row2_col5, #T_59a58_row2_col6, #T_59a58_row3_col0, #T_59a58_row3_col1, #T_59a58_row3_col2, #T_59a58_row3_col3, #T_59a58_row3_col4, #T_59a58_row3_col5, #T_59a58_row3_col6, #T_59a58_row4_col0, #T_59a58_row4_col1, #T_59a58_row4_col2, #T_59a58_row4_col3, #T_59a58_row4_col4, #T_59a58_row4_col5, #T_59a58_row4_col6, #T_59a58_row5_col0, #T_59a58_row5_col1, #T_59a58_row5_col2, #T_59a58_row5_col3, #T_59a58_row5_col4, #T_59a58_row5_col5, #T_59a58_row5_col6, #T_59a58_row6_col0, #T_59a58_row6_col1, #T_59a58_row6_col2, #T_59a58_row6_col3, #T_59a58_row6_col4, #T_59a58_row6_col5, #T_59a58_row6_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T
col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_59a58_row5_col0" class="data row5 col0" >f9308c58-4cbf-4698-9abf-5627eba97654</td>
#       <td id="T_59a58_row5_col1" class="data row5 col1" >s2h22</td>
#       <td id="T_59a58_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_59a58_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_59a58_row5_col4" class="data row5 col4" >EDUKY</td>
#       <td id="T_59a58_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_59a58_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_59a58_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_59a58_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_59a58_row6_col0" class="data row6 col0" >d09abf00-40d4-4c20-95b5-0d9e54f67e04</td>
#       <td id="T_59a58_row6_col1" class="data row6 col1" >s2h23</td>
#       <td id="T_59a58_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_59a58_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_59a58_row6_col4" class="data row6 col4" >EDUKY</td>
#       <td id="T_59a58_row6_col5" class="data row6 col5" >None</td>
#       <td id="T_59a58_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_59a58_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_59a58_row6_col8" class="data row6 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a7f07 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_a7f07 th {
#   text-align: left;
# }
# #T_a7f07 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a7f07 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a7f07 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a7f07_row0_col0, #T_a7f07_row0_col1, #T_a7f07_row0_col2, #T_a7f07_row0_col3, #T_a7f07_row0_col4, #T_a7f07_row0_col5, #T_a7f07_row0_col6, #T_a7f07_row0_col7, #T_a7f07_row0_col8, #T_a7f07_row0_col9, #T_a7f07_row0_col10, #T_a7f07_row0_col11, #T_a7f07_row0_col12, #T_a7f07_row1_col0, #T_a7f07_row1_col1, #T_a7f07_row1_col2, #T_a7f07_row1_col3, #T_a7f07_row1_col4, #T_a7f07_row1_col5, #T_a7f07_row1_col6, #T_a7f07_row1_col7, #T_a7f07_row1_col8, #T_a7f07_row1_col9, #T_a7f07_row1_col10, #T_a7f07_row1_col11, #T_a7f07_row1_col12, #T_a7f07_row2_col0, #T_a7f07_row2_col1, #T_a7f07_row2_col2, #T_a7f07_row2_col3, #T_a7f07_row2_col4, #T_a7f07_row2_col5, #T_a7f07_row2_col6, #T_a7f07_row2_col7, #T_a7f07_row2_col8, #T_a7f07_row2_col9, #T_a7f07_row2_col10, #T_a7f07_row2_col11, #T_a7f07_row2_col12, #T_a7f07_row3_col0, #T_a7f07_row3_col1, #T_a7f07_row3_col2, #T_a7f07_row3_col3, #T_a7f07_row3_col4, #T_a7f07_row3_col5, #T_a7f07_row3_col6, #T_a7f07_row3_col7, #T_a7f07_row3_col8, #T_a7f07_row3_col9, #T_a7f07_row3_col10, #T_a7f07_row3_col11, #T_a7f07_row3_col12, #T_a7f07_row4_col0, #T_a7f07_row4_col1, #T_a7f07_row4_col2, #T_a7f07_row4_col3, #T_a7f07_row4_col4
# Time to print interfaces 352 seconds
# Installing needed tools
# 1/8 installs finished
# 2/8 installs finished
# 3/8 installs finished
# 4/8 installs finished
# 5/8 installs finished
# 6/8 installs finished
# 7/8 installs finished
# 8/8 installs finished
# 1/8 logging jobs finished
# 2/8 logging jobs finished
# 3/8 logging jobs finished
# 4/8 logging jobs finished
# 5/8 logging jobs finished
# 6/8 logging jobs finished
# 7/8 logging jobs finished
# 8/8 logging jobs finished
# 1/8 upload jobs finished
# 2/8 upload jobs finished
# 3/8 upload jobs finished
# 4/8 upload jobs finished
# 5/8 upload jobs finished
# 6/8 upload jobs finished
# 7/8 upload jobs finished
# 8/8 upload jobs finished
# Finished installing needed tools
# Configuring node interfaces
# Configuring s1...Done
# Configuring s2...Done
# Configuring h11...Done
# Configuring h12...Done
# Configuring h13...Done
# Configuring h21...Done
# Configuring h22...Done
# Configuring h23...Done
#
#
# 1/14 address configuration jobs finished
# 2/14 address configuration jobs finished
# 3/14 address configuration jobs finished
# 4/14 address configuration jobs finished
# 5/14 address configuration jobs finished
# 6/14 address configuration jobs finished
# 7/14 address configuration jobs finished
# 8/14 address configuration jobs finished
# 9/14 address configuration jobs finished
# 10/14 address configuration jobs finished
# 11/14 address configuration jobs finished
# 12/14 address configuration jobs finished
# 13/14 address configuration jobs finished
# 14/14 address configuration jobs finished
# Finished configuring addresses
# Code execution will be logged to 'jupyter_code_log.txt'.

# %%
# If the above had any node fail, UNCOMMENT the line below and execute this cell, then try again
# slice.delete()

# %% [markdown]
# # P4 Programming
# The main objective of this assignment is to create P4 code which will configure the switches (s1 and s2 in the topology) to function as IPv6 routers and firewalls. A copy of the P4 program from the tutorial, which created an IPv4 router, is provided as a starter template in [assignment.p4](./assignment.p4).
#
# The routing requirements are that:
# - hosts on each subnet can ping each other
# - hosts can ping hosts on the other subnet, and the switches route to the other subnet using LPM
#
# The firewall requirement is that TCP or UDP packets must have one of the ports listed below as either the source or destination port.
#
# Besides modifying P4 code, you will also need to edit [add_rules_s1.sh](./add_rules_s1.sh) and [add_rules_s2.sh](./add_rules_s2.sh) to contain the control plane commands the switches need to be configured with.
#
# In a Jupyter cell, `funcs.start_switches(switches, verbose)` and `funcs.stop_switches(switches, verbose)` will respectively start and stop the switches (see the start and end of the Testing section).

# %%
# For convenience, list all the values from the config file
funcs.print_values(configs, macs, ips)
# Out:
# s1's MAC addresses are (in order from port 0 to port 3):
# 1c:88:18:16:d2:41
# 04:66:be:6a:81:dc
# d0:71:79:3d:7e:0a
# 80:ce:01:83:8c:e4
# s2's MAC addresses are (in order from port 0 to port 3):
# c4:9b:87:6c:82:15
# d4:bb:4e:80:f5:23
# 6c:4c:de:68:89:30
# 20:2f:38:b6:87:8a
# For the above, s1 and s2 are connected to each other on their port 0. Port 1 connects to h11 or h21, port 2 to h12 or h22, and port 3 to h13 or h23.
# h11's MAC address is f0:b6:f2:1f:4e:1b and its IPv6 address is 2001:db8:28fe:5613::3e2d:df8e
# h12's MAC address is 7c:ee:f9:5d:ba:3a and its IPv6 address is 2001:db8:28fe:5613::fb6c:822
# h13's MAC address is e8:a8:94:61:ad:f8 and its IPv6 address is 2001:db8:28fe:5613::c28e:73e3
# h21's MAC address is 40:ba:9b:57:c3:7a and its IPv6 address is 2001:db8:347c:d902::840:5a3b
# h22's MAC address is dc:56:0d:1e:81:15 and its IPv6 address is 2001:db8:347c:d902::9610:d3ec
# The allowed TCP ports are: 517 648 676 849
# The allowed UDP ports are: 45 178 885 988
# A reminder that in the topology, h23 is ignored and autoconfigured later.

# %% [markdown]
# # SSH Keys
# The below cell will print the ssh keys, which you can enter into a new terminal tab to ssh to that client. Useful for testing/debugging your P4 code by:
# <list>
#     <li> SSHing into two terminals for s1 - run ./run_bm2_s1.sh in s1, let it start, then ./add_rules_s1.sh, and the same for s2 </li>
#     <li> SSHing into a host and attempting to ping another with ping6, or using send.py to send a packet with specific TCP/UDP ports </li>
# </list>

# %%
for node in vslice.get_nodes():
    print(f"{node.get_name()}: {node.get_ssh_command()}")
# Out:
# h11: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fee2:9435
# h12: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fed1:442b
# h13: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:feea:3e5d
# s1: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe93:875d
# h21: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe20:2977
# h22: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe3f:87b7
# h23: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe45:a73b
# s2: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fea7:64d9

# %% [markdown]
# # Testing
# The below cells will automatically test your P4 and sh scripts. The score breakdown for this assignment is:
# - 2.5pts for h11 through h21 being able to ping each other
# - 5 pts for the switches correctly filtering TCP and UDP ports
# - 2.5pts for correctly routing to a random host added to subnet 2
#
# There is a total of 10 points. These cells should not be modified, and they should be run in order.

# %%
# Start switches before the tests - this also uploads your most recent P4 and add_rules files
funcs.start_switches(switches, verbose)
# Out:
# Starting switches
# Compiling P4...
#
#
# Compiling P4...
#
#
# Switches started

# %%
# Ping Test
pingscore = funcs.ping_test(hosts, ips)
# Out:
# h11 failed to ping h12
# h11 failed to ping h13
# h11 failed to ping h21
# h11 failed to ping h22
# h11 0/4 pings successful, 0pts
# h12 failed to ping h11
# h12 failed to ping h13
# h12 failed to ping h21
# h12 failed to ping h22
# h12 0/4 pings successful, 0pts
# h13 failed to ping h11
# h13 failed to ping h12

# %%
# Port Test
portscore = funcs.port_test(hosts, ips, configs, ifaces, student_id, verbose)
# Out:
# h22: Starting receiver
# h12: Send allowed TCP packets
# h12: Send non-allowed TCP packet
# h12: Send allowed UDP packets
# h12: Send non-allowed UDP packet
# Total port score: 0/5.0pts

# %%
# h23 Test
h23score = funcs.h23_test(hosts, ips, switches, ifaces, configs, macs, gateways, verbose)

print(f"Total Score: {pingscore+portscore+h23score}/10pts")
# Out:
# h23 failed to ping h11
# h23 failed to ping h12
# h23 failed to ping h13
# h23 2/5 pings successful, 0pts
# Total Score: 0/10pts

# %%
# To stop the switches, so they can be restarted (such as to update their P4 code)
funcs.stop_switches(switches, verbose)

# %%
# Run this to generate the .tar.gz file you will submit to Canvas
funcs.create_tar(student_id, hosts, switches, override=True)
# Out:
# Done! Please submit btursunbayev.tar.gz on Canvas!

# %%
# Uncomment and delete your slice when you're finished
# vslice.delete()
